# %% [markdown]
# # Exploración inicial del Titanic
#
# Este notebook carga el dataset del Titanic y realiza una primera exploración con Pandas, Matplotlib y Seaborn.

# %%
# !pip install pandas
# !pip install matplotlib.pyplot
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=0.25->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=0.25->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\myria\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.17.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- 1. Cargar dataset ---
df = pd.read_csv("data/comida.csv")

# --- 2. Primer vistazo ---
print("Dimensiones del dataset:", df.shape)
print("\nColumnas disponibles:\n", df.columns.tolist())
print("\nPrimeras filas:\n", df.head())
# Out:
# Dimensiones del dataset: (11, 4)
#
# Columnas disponibles:
#  ['INGREDIENTE', 'DOCURA', 'CROCANCIA', 'TIPO']
#
# Primeras filas:
#    INGREDIENTE  DOCURA  CROCANCIA      TIPO
# 0        MACA      10          9     FRUTA
# 1       BACON       1          4  PROTEINA
# 2      BANANA      10          1     FRUTA
# 3     CENOURA       7         10   VEGETAL
# 4        AIPO       3         10   VEGETAL

# %%
# --- 3. Información general ---
print("\nInformación del dataset:")
print(df.info())

print("\nEstadísticas numéricas:")
print(df.describe())
# Out:
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   INGREDIENTE  11 non-null     object
#  1   DOCURA       11 non-null     int64
#  2   CROCANCIA    11 non-null     int64
#  3   TIPO         11 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 484.0+ bytes
# None
#
# Estadísticas numéricas:
#           DOCURA  CROCANCIA
# count  11.000000  11.000000
# mean    5.272727   5.545455
# std     3.319365   3.236159
# min     1.000000   1.000000
# 25%     3.000000   3.500000
# 50%     5.000000   5.000000
# 75%     7.500000   8.000000
# max    10.000000  10.000000

# %%
# --- 4. Valores faltantes ---
print("\nValores nulos por columna:")
print(df.isnull().sum())
# Out:
# Valores nulos por columna:
# INGREDIENTE    0
# DOCURA         0
# CROCANCIA      0
# TIPO           0
# dtype: int64

# %%
# --- 5. Preguntas exploratorias ---
survived_counts = df["INGREDIENTE"].value_counts()
print("\nIngredientes (0 = no, 1 = sí):\n", survived_counts)

print("\nEdad media de los supervivientes:", df[df["INGREDIENTE"]==1]["TIPO"].mean())

print("\nDistribución de pasajeros por clase:")
print(df["DOCURA"].value_counts())
# Out:
# Supervivientes (0 = no, 1 = sí):
#  INGREDIENTE
# MACA            1
# BACON           1
# BANANA          1
# CENOURA         1
# AIPO            1
# QUEIJO          1
# UVA             1
# FEIJAO VERDE    1
# NOZ             1
# LARANJA         1
# TOMATE          1
# Name: count, dtype: int64
#
# Edad media de los supervivientes: nan
#
# Distribución de pasajeros por clase:
# DOCURA
# 3     3
# 10    2
# 1     2
# 7     2
# 8     1
# 5     1
# Name: count, dtype: int64

# %%
# --- 6. Visualizaciones ---
sns.set_style("whitegrid")

sns.countplot(data=df, x="Survived", hue="Sex")
plt.title("Supervivencia por sexo")
plt.show()

df["Age"].hist(bins=30, edgecolor="black")
plt.title("Distribución de edades")
plt.xlabel("Edad")
plt.ylabel("Número de pasajeros")
plt.show()

sns.countplot(data=df, x="Pclass", hue="Survived")
plt.title("Supervivencia por clase")
plt.show()
